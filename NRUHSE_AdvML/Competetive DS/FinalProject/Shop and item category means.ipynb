# %%
import os
import numpy as np
import pandas as pd
#import matplotlib as mpl
import matplotlib.pyplot as plt
#import matplotlib.dates as mdates
# %matplotlib inline

# %%
DATA_FOLDER = './data/'

train = pd.read_csv(os.path.join(DATA_FOLDER, 'sales_train.csv.gz'))
test = pd.read_csv(os.path.join(DATA_FOLDER, 'test.csv.gz'))
items = pd.read_csv(os.path.join(DATA_FOLDER, 'items.csv'))
categories = pd.read_csv(os.path.join(DATA_FOLDER, 'item_categories.csv'))
shops = pd.read_csv(os.path.join(DATA_FOLDER, 'shops.csv'))

# %%
max_train_date_block_num = train.date_block_num.max()

# %%
from itertools import product

# For every month we create a grid from all shops/items combinations from that month
grid = [] 
for block_num in train['date_block_num'].unique():
    cur_shops = train[train['date_block_num']==block_num]['shop_id'].unique()
    cur_items = train[train['date_block_num']==block_num]['item_id'].unique()
    grid.append(np.array(list(product(*[cur_shops, cur_items, [block_num]])),dtype='int32'))

#turn the grid into pandas dataframe
index_cols = ['shop_id', 'item_id', 'date_block_num']
grid = pd.DataFrame(np.vstack(grid), columns = index_cols, dtype=np.int32)

#get aggregated values for (shop_id, item_id, month)
gb = train.groupby(index_cols,as_index=False).agg({'item_cnt_day':{'item_cnt_month':'sum'}})

#fix column names
gb.columns = [col[0] if col[-1]=='' else col[-1] for col in gb.columns.values]
#join aggregated data to the grid
all_data = pd.merge(grid,gb,how='left',on=index_cols).fillna(0)
#sort the data
all_data.sort_values(['date_block_num','shop_id','item_id'],inplace=True)
all_data.head()
# Out:
# /home/mortennp/anaconda3/envs/AdvML3_6/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#         shop_id  item_id  date_block_num  item_cnt_month
# 139255        0       19               0             0.0
# 141495        0       27               0             0.0
# 144968        0       28               0             0.0
# 142661        0       29               0             0.0
# 138947        0       32               0             6.0

# %%
all_data.describe()
# Out:
#             shop_id       item_id  date_block_num  item_cnt_month
# count  1.091385e+07  1.091385e+07    1.091385e+07    1.091385e+07
# mean   3.118720e+01  1.130926e+04    1.497334e+01    3.342731e-01
# std    1.734959e+01  6.209978e+03    9.495618e+00    3.417243e+00
# min    0.000000e+00  0.000000e+00    0.000000e+00   -2.200000e+01
# 25%    1.600000e+01  5.976000e+03    7.000000e+00    0.000000e+00
# 50%    3.000000e+01  1.139100e+04    1.400000e+01    0.000000e+00
# 75%    4.600000e+01  1.660500e+04    2.300000e+01    0.000000e+00
# max    5.900000e+01  2.216900e+04    3.300000e+01    2.253000e+03

# %%
train_rup = all_data
train_rup.item_cnt_month = train_rup.item_cnt_month.clip(0, 20)
train_rup.head()
# Out:
#         shop_id  item_id  date_block_num  item_cnt_month
# 139255        0       19               0             0.0
# 141495        0       27               0             0.0
# 144968        0       28               0             0.0
# 142661        0       29               0             0.0
# 138947        0       32               0             6.0

# %%
shop_means = train_rup.groupby(['shop_id', 'date_block_num']).mean()[['item_cnt_month']]
shop_means = shop_means.rename(columns={'item_cnt_month':'mean_shop_cnt_month'}).reset_index()
print(len(shop_means))
print(max_train_date_block_num * len(shops))
shop_means.head()
# Out:
# 1586
# 1980
#    shop_id  date_block_num  mean_shop_cnt_month
# 0        0               0             0.666790
# 1        0               1             0.712537
# 2        1               0             0.361306
# 3        1               1             0.405730
# 4        2               0             0.141220

# %%
category_means = train_rup.merge(items, how='left').groupby(['date_block_num', 'item_category_id']).mean()[['item_cnt_month']]
category_means = category_means.rename(columns={'item_cnt_month':'mean_category_cnt_month'}).reset_index()
print(len(category_means))
print(max_train_date_block_num * len(categories))
category_means.head()
# Out:
# 2077
# 2772
#    date_block_num  item_category_id  mean_category_cnt_month
# 0               0                 0                 0.022222
# 1               0                 1                 0.022222
# 2               0                 2                 0.835435
# 3               0                 3                 4.422222
# 4               0                 4                 0.513131

# %%
train_rup = train_rup.merge(shop_means)
print(len(train_rup))
train_rup.head()
# Out:
# 10913850
#    shop_id  item_id  date_block_num  item_cnt_month  mean_shop_cnt_month
# 0        0       19               0             0.0              0.66679
# 1        0       27               0             0.0              0.66679
# 2        0       28               0             0.0              0.66679
# 3        0       29               0             0.0              0.66679
# 4        0       32               0             6.0              0.66679

# %%
train_rup = train_rup.merge(items)
print(len(train_rup))
train_rup.head()
# Out:
# 10913850
#    shop_id  item_id  date_block_num  item_cnt_month  mean_shop_cnt_month  \
# 0        0       19               0             0.0             0.666790
# 1        1       19               0             0.0             0.361306
# 2        2       19               0             0.0             0.141220
# 3        3       19               0             0.0             0.094516
# 4        4       19               0             0.0             0.257425
#
#                    item_name  item_category_id
# 0  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40
# 1  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40
# 2  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40
# 3  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40
# 4  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40

# %%
train_rup = train_rup.merge(category_means)
print(len(train_rup))
train_rup.head()
# Out:
# 10913850
#    shop_id  item_id  date_block_num  item_cnt_month  mean_shop_cnt_month  \
# 0        0       19               0             0.0             0.666790
# 1        1       19               0             0.0             0.361306
# 2        2       19               0             0.0             0.141220
# 3        3       19               0             0.0             0.094516
# 4        4       19               0             0.0             0.257425
#
#                    item_name  item_category_id  mean_category_cnt_month
# 0  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40                 0.293846
# 1  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40                 0.293846
# 2  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40                 0.293846
# 3  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40                 0.293846
# 4  /ЗОЛОТАЯ КОЛЛЕКЦИЯ м/ф-72                40                 0.293846

# %%
train_rup = train_rup.loc[:, ['shop_id', 'item_id', 'date_block_num', 'mean_shop_cnt_month', 'mean_category_cnt_month', 'item_cnt_month']]
train_rup = train_rup.assign(prev_date_block_num = train_rup.date_block_num - 1)
train_rup.head()
# Out:
#    shop_id  item_id  date_block_num  mean_shop_cnt_month  \
# 0        0       19               0             0.666790
# 1        1       19               0             0.361306
# 2        2       19               0             0.141220
# 3        3       19               0             0.094516
# 4        4       19               0             0.257425
#
#    mean_category_cnt_month  item_cnt_month  prev_date_block_num
# 0                 0.293846             0.0                   -1
# 1                 0.293846             0.0                   -1
# 2                 0.293846             0.0                   -1
# 3                 0.293846             0.0                   -1
# 4                 0.293846             0.0                   -1

# %%
merged = train_rup.merge(train_rup, how='left', left_on=['prev_date_block_num', 'shop_id', 'item_id'], right_on=['date_block_num', 'shop_id', 'item_id'] )
merged.head()
# Out:
#    shop_id  item_id  date_block_num_x  mean_shop_cnt_month_x  \
# 0        0       19                 0               0.666790
# 1        1       19                 0               0.361306
# 2        2       19                 0               0.141220
# 3        3       19                 0               0.094516
# 4        4       19                 0               0.257425
#
#    mean_category_cnt_month_x  item_cnt_month_x  prev_date_block_num_x  \
# 0                   0.293846               0.0                     -1
# 1                   0.293846               0.0                     -1
# 2                   0.293846               0.0                     -1
# 3                   0.293846               0.0                     -1
# 4                   0.293846               0.0                     -1
#
#    date_block_num_y  mean_shop_cnt_month_y  mean_category_cnt_month_y  \
# 0               NaN                    NaN                        NaN
# 1               NaN                    NaN                        NaN
# 2               NaN                    NaN                        NaN
# 3               NaN                    NaN                        NaN
# 4               NaN                    NaN                        NaN
#
#    item_cnt_month_y  prev_date_block_num_y
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 3               NaN                    NaN
# 4               NaN                    NaN

# %%
buf = merged.loc[:, ['shop_id', 'item_id', 'date_block_num_x', 'mean_shop_cnt_month_y', 'mean_category_cnt_month_y', 'item_cnt_month_y', 'item_cnt_month_x']]
buf.rename(columns={'date_block_num_x':'date_block_num', 'item_cnt_month_x': 'item_cnt_month', 'mean_category_cnt_month_y':'mean_category_cnt_prev_month', 'mean_shop_cnt_month_y':'mean_shop_cnt_prev_month', 'item_cnt_month_y':'item_cnt_prev_month'}, inplace=True)
buf.head()
# Out:
#    shop_id  item_id  date_block_num  mean_shop_cnt_prev_month  \
# 0        0       19               0                       NaN
# 1        1       19               0                       NaN
# 2        2       19               0                       NaN
# 3        3       19               0                       NaN
# 4        4       19               0                       NaN
#
#    mean_category_cnt_prev_month  item_cnt_prev_month  item_cnt_month
# 0                           NaN                  NaN             0.0
# 1                           NaN                  NaN             0.0
# 2                           NaN                  NaN             0.0
# 3                           NaN                  NaN             0.0
# 4                           NaN                  NaN             0.0

# %%
#buf = buf.merge(means, how='left', left_on=['shop_id', 'item_id'], right_on=['shop_id', 'item_id'])
buf = buf.assign(valid=pd.Series(~buf.item_cnt_prev_month.isnull(), dtype=int))
buf.item_cnt_prev_month.fillna(-1, inplace=True)
buf.mean_shop_cnt_prev_month.fillna(-1, inplace=True)
buf.mean_category_cnt_prev_month.fillna(-1, inplace=True)
buf.head()
# Out:
#    shop_id  item_id  date_block_num  mean_shop_cnt_prev_month  \
# 0        0       19               0                      -1.0
# 1        1       19               0                      -1.0
# 2        2       19               0                      -1.0
# 3        3       19               0                      -1.0
# 4        4       19               0                      -1.0
#
#    mean_category_cnt_prev_month  item_cnt_prev_month  item_cnt_month  valid
# 0                          -1.0                 -1.0             0.0      0
# 1                          -1.0                 -1.0             0.0      0
# 2                          -1.0                 -1.0             0.0      0
# 3                          -1.0                 -1.0             0.0      0
# 4                          -1.0                 -1.0             0.0      0

# %%
buf.describe()
# Out:
#             shop_id       item_id  date_block_num  mean_shop_cnt_prev_month  \
# count  1.091385e+07  1.091385e+07    1.091385e+07              1.091385e+07
# mean   3.118720e+01  1.130926e+04    1.497334e+01              5.319350e-03
# std    1.734959e+01  6.209978e+03    9.495618e+00              5.778523e-01
# min    0.000000e+00  0.000000e+00    0.000000e+00             -1.000000e+00
# 25%    1.600000e+01  5.976000e+03    7.000000e+00              8.653093e-02
# 50%    3.000000e+01  1.139100e+04    1.400000e+01              1.986196e-01
# 75%    4.600000e+01  1.660500e+04    2.300000e+01              2.879637e-01
# max    5.900000e+01  2.216900e+04    3.300000e+01              1.799243e+00
#
#        mean_category_cnt_prev_month  item_cnt_prev_month  item_cnt_month  \
# count                  1.091385e+07         1.091385e+07    1.091385e+07
# mean                   1.477373e-02         5.538870e-02    2.982399e-01
# std                    6.634297e-01         1.319458e+00    1.222373e+00
# min                   -1.000000e+00        -1.000000e+00    0.000000e+00
# 25%                    5.189063e-02         0.000000e+00    0.000000e+00
# 50%                    1.965922e-01         0.000000e+00    0.000000e+00
# 75%                    2.514297e-01         0.000000e+00    0.000000e+00
# max                    1.924000e+01         2.000000e+01    2.000000e+01
#
#               valid
# count  1.091385e+07
# mean   7.731313e-01
# std    4.188070e-01
# min    0.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
target_col = 'item_cnt_month'
X = buf.loc[:, buf.columns != target_col].values
print(X) #X.head()
# Out:
# [[ 0.000e+00  1.900e+01  0.000e+00 ... -1.000e+00 -1.000e+00  0.000e+00]
#  [ 1.000e+00  1.900e+01  0.000e+00 ... -1.000e+00 -1.000e+00  0.000e+00]
#  [ 2.000e+00  1.900e+01  0.000e+00 ... -1.000e+00 -1.000e+00  0.000e+00]
#  ...
#  [ 5.700e+01  4.931e+03  3.300e+01 ... -1.000e+00 -1.000e+00  0.000e+00]
#  [ 5.800e+01  4.931e+03  3.300e+01 ... -1.000e+00 -1.000e+00  0.000e+00]
#  [ 5.900e+01  4.931e+03  3.300e+01 ... -1.000e+00 -1.000e+00  0.000e+00]]

# %%
y = buf.loc[:, [target_col]].values.ravel()
print(y) #y.head()
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
def gen_time_split(X, n_splits):
    for i in range(n_splits):
        print(i)
        first_vali_date_block_num = max_train_date_block_num - i
        vali_indices = X.loc[:,'date_block_num'] == first_vali_date_block_num
        train_indices = X.loc[:,'date_block_num'] < first_vali_date_block_num
        yield (train_indices[train_indices].index, vali_indices[vali_indices].index)

# %%
cv = gen_time_split(buf, 3)

# %%
from sklearn.ensemble import GradientBoostingRegressor
est = GradientBoostingRegressor(n_estimators=50, max_depth=7, loss='ls', verbose=1)

# %%
#lr = 1 / np.logspace(0.0, 1.0, num=5)[2:]
#lr = np.array([0.3, 0.45, 0.6])
#lr = np.linspace(0.3, 0.6, 5)
lr = np.array([0.3])
print(lr)
# Out:
# [0.3]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'learning_rate':lr}
gs = GridSearchCV(est, param_grid, cv=cv, refit=True, n_jobs=4, scoring='r2', verbose=1)
#gs.fit(X, y)

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
pipe = Pipeline(steps=[('Search', gs)]) #('Scaling', StandardScaler()),

# %%
#pipe.fit(X,y)
est.fit(X,y)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3973           36.39m
#          2           1.3188           35.37m
#          3           1.2541           34.79m
#          4           1.2020           33.83m
#          5           1.1594           32.84m
#          6           1.1243           32.23m
#          7           1.0958           31.52m
#          8           1.0726           30.81m
#          9           1.0536           30.11m
#         10           1.0382           29.46m
#         20           0.9712           22.21m
#         30           0.9499           14.82m
#         40           0.9361            7.48m
#         50           0.9264            0.00s
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=7, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=50, n_iter_no_change=None, presort='auto',
#              random_state=None, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=1, warm_start=False)

# %% [markdown]
# from sklearn.model_selection import cross_val_score
# scores = cross_val_score(est, X, y, cv=cv)
# print(scores)
# #print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %%
print(gs.cv_results_['mean_test_score'])
print(gs.cv_results_['params'])
#gs.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-27b839b7e505> in <module>
# ----> 1 print(gs.cv_results_['mean_test_score'])
#       2 print(gs.cv_results_['params'])
#       3 #gs.best_estimator_
#
# NameError: name 'gs' is not defined

# %%
from sklearn.metrics import mean_squared_error
y_pred = est.predict(X) #pipe.predict(X)
mse = mean_squared_error(y, y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 0.926443010735238
# 0.9625190962963998

# %%
X_test = test.assign(date_block_num=max_train_date_block_num+1, prev_date_block_num=max_train_date_block_num).drop(columns=['ID'])
X_test.head()
# Out:
#    shop_id  item_id  date_block_num  prev_date_block_num
# 0        5     5037              34                   33
# 1        5     5320              34                   33
# 2        5     5233              34                   33
# 3        5     5232              34                   33
# 4        5     5268              34                   33

# %%
merged2 = X_test.merge(train_rup, how='left', left_on=['prev_date_block_num', 'shop_id', 'item_id'], right_on=['date_block_num', 'shop_id', 'item_id'] )
merged2.head()
# Out:
#    shop_id  item_id  date_block_num_x  prev_date_block_num_x  \
# 0        5     5037                34                     33
# 1        5     5320                34                     33
# 2        5     5233                34                     33
# 3        5     5232                34                     33
# 4        5     5268                34                     33
#
#    date_block_num_y  mean_shop_cnt_month  mean_category_cnt_month  \
# 0              33.0             0.190098                 0.379047
# 1               NaN                  NaN                      NaN
# 2              33.0             0.190098                 0.379047
# 3              33.0             0.190098                 0.337353
# 4               NaN                  NaN                      NaN
#
#    item_cnt_month  prev_date_block_num_y
# 0             0.0                   32.0
# 1             NaN                    NaN
# 2             1.0                   32.0
# 3             0.0                   32.0
# 4             NaN                    NaN

# %%
buf2 = merged2.loc[:, ['shop_id', 'item_id', 'date_block_num_x', 'mean_shop_cnt_month', 'mean_category_cnt_month', 'item_cnt_month']]
buf2.rename(columns={'date_block_num_x':'date_block_num', 'mean_shop_cnt_month':'mean_shop_cnt_prev_month', 'mean_category_cnt_month':'mean_category_cnt_prev_month', 'item_cnt_month':'item_cnt_prev_month'}, inplace=True)
buf2.head()
# Out:
#    shop_id  item_id  date_block_num  mean_shop_cnt_prev_month  \
# 0        5     5037              34                  0.190098
# 1        5     5320              34                       NaN
# 2        5     5233              34                  0.190098
# 3        5     5232              34                  0.190098
# 4        5     5268              34                       NaN
#
#    mean_category_cnt_prev_month  item_cnt_prev_month
# 0                      0.379047                  0.0
# 1                           NaN                  NaN
# 2                      0.379047                  1.0
# 3                      0.337353                  0.0
# 4                           NaN                  NaN

# %%
buf2 = buf2.assign(valid=pd.Series(~buf2.item_cnt_prev_month.isnull(), dtype=int))
buf2.item_cnt_prev_month.fillna(-1, inplace=True)
buf2.mean_shop_cnt_prev_month.fillna(-1, inplace=True)
buf2.mean_category_cnt_prev_month.fillna(-1, inplace=True)
buf2.head()
# Out:
#    shop_id  item_id  date_block_num  mean_shop_cnt_prev_month  \
# 0        5     5037              34                  0.190098
# 1        5     5320              34                 -1.000000
# 2        5     5233              34                  0.190098
# 3        5     5232              34                  0.190098
# 4        5     5268              34                 -1.000000
#
#    mean_category_cnt_prev_month  item_cnt_prev_month  valid
# 0                      0.379047                  0.0      1
# 1                     -1.000000                 -1.0      0
# 2                      0.379047                  1.0      1
# 3                      0.337353                  0.0      1
# 4                     -1.000000                 -1.0      0

# %%
X_test = buf2.values

# %%
y_pred_test = est.predict(X_test) #pipe.predict(X_test)
print(y_pred_test)
# Out:
# [0.20531101 0.15155253 0.55934457 ... 0.08583404 0.08857669 0.1006706 ]

# %%
submission = test.assign(item_cnt_month=y_pred_test)[['item_cnt_month']]
submission.describe()
# Out:
#        item_cnt_month
# count   214200.000000
# mean         0.257611
# std          0.642333
# min         -0.034788
# 25%          0.088577
# 50%          0.128054
# 75%          0.221238
# max         19.730250

# %%
submission.head()
# Out:
#    item_cnt_month
# 0        0.205311
# 1        0.151553
# 2        0.559345
# 3        0.178515
# 4        0.172570

# %%
submission.to_csv('ShopAndCategoryMeans_50.csv', index_label='ID') #header=['ID', 'item_cnt_month'])

# %%
# !gzip ShopAndCategoryMeans_50.csv
# !ls
# Out:
# Baseline.ipynb	   EDA.ipynb	   ShopAndCategoryMeans_50.csv.gz
# combos.csv.gz	   lagged2.csv.gz  ShopAndCategoryMeans.csv
# Combos.ipynb	   lagged3.csv.gz  ShopAndCategoryMeans_xgb.csv.gz
# combos_xgb.csv.gz  lagged.csv.gz   Shop and item category means.ipynb
# data		   Lagged.ipynb    submission.csv.gz

# %% [markdown]
# 0.3 is best learning rate so far.
#
# [
#  (split1_train_idxs, split1_test_idxs),
#  (split2_train_idxs, split2_test_idxs),
#  (split3_train_idxs, split3_test_idxs),
#  ...
# ]
#
# "Submissions are evaluated by root mean squared error (RMSE). True target values are clipped into [0,20] range."
#
# and
#
# "For each id in the test set, you must predict a total number of sales."
#
# and
#
# "Submission is for date_block_num 34"
#
# and
#
# "
# My CV strategy is 5-fold moving window:
#
# fold 1: Train on month 0 to 32 and validate on 33
# fold 2: Train on month 0 to 31 and validate on 32
# …
# fold 5: Train on month 0 to 28 and validate on 29
# "
#
# and
#
# - mean encodings
# - lag
# - text extraction on item and category names

# %%
#import sys
#!conda install --yes --prefix {sys.prefix} xgboost
#{sys.executable} -m pip install xgboost

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(buf.loc[:, buf.columns != target_col], label=y)
param = {'max_depth':7, 'eta':0.3, 'silent':0, 'objective':'reg:linear', 'eval_metrix':'rmse' }
num_round = 100
bst = xgb.train(param, dtrain, num_round)
# Out:
# [20:32:31] Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [20:32:38] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:32:43] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:32:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:32:55] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:00] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:06] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:11] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:17] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:23] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:28] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:34] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:40] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:45] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:51] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:33:56] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:02] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:08] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:13] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:19] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:30] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:36] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:42] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:53] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:34:58] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:04] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:09] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:15] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:21] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:26] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:32] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:38] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:43] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:35:54] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:00] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:05] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:10] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:16] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:21] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:27] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:32] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:38] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:44] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:36:55] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:01] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:07] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:12] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:18] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:30] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:35] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:41] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:52] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:37:57] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:03] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 190 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:08] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:13] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:18] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:24] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:30] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:36] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:41] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:47] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:53] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:38:59] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:04] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:10] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:15] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:21] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:26] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:32] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:37] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:43] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:48] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [20:39:54] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:00] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:06] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:11] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:17] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:23] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:28] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:34] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:40] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:46] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:51] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:40:57] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:03] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:09] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:14] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:20] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 242 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:26] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:32] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:38] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:44] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:49] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7
# [20:41:55] /workspace/src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=7

# %%
y_pred = bst.predict(dtrain)
mse = mean_squared_error(y, y_pred)
print(mse)
print(np.sqrt(mse))
# Out:
# 0.889699998879066
# 0.9432390995283572

# %%
# make prediction
dtest = xgb.DMatrix(buf2)
y_pred_test = bst.predict(dtest)
y_pred_test
# Out:
# array([0.15239403, 0.07205728, 0.40105173, ..., 0.07691392, 0.08787793,
#        0.04896444], dtype=float32)
